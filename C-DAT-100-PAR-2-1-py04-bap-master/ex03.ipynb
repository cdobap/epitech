# %%
import seaborn as sns
import matplotlib.pyplot as plt
import time
import pickle
from IPython.display import clear_output

# %% [markdown]
# EXERCICE 03
# DINAMYC GRAPH RELOAD

# %%
while True:
    clear_output(wait=True)
    file = open('ps5-dataframe.pickle', 'rb')
    data = pickle.load(file)
    file.close()
    data1 = data
    sns.boxplot(x="day", y="price", data=data)
    plt.show()
    time.sleep(300)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-8aee987ceeb5> in <module>
#       7     sns.boxplot(x="day", y="price", data=data)
#       8     plt.show()
# ----> 9     time.sleep(20)
#
# KeyboardInterrupt:

# %% [markdown]
# TO COMPARE THE DINAMYC CHANGE WITH THE GRAPH ABOVE

# %%
sns.boxplot(x="day", y="price", data=data)
plt.show()
