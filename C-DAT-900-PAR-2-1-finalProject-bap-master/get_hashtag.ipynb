# %%
import pandas as pd
import tweepy

# %%
def printtweetdata(n, ith_tweet):
    print()
    print(f"Tweet {n}:")
    print(f"Username:{ith_tweet[0]}")
    print(f"Description:{ith_tweet[1]}")
    print(f"Location:{ith_tweet[2]}")
    print(f"Following Count:{ith_tweet[3]}")
    print(f"Follower Count:{ith_tweet[4]}")
    print(f"Total Tweets:{ith_tweet[5]}")
    print(f"Retweet Count:{ith_tweet[6]}")
    print(f"Tweet Text:{ith_tweet[7]}")
    print(f"Hashtags Used:{ith_tweet[8]}")  
    print(f"datetime:{ith_tweet[9]}")

def scrape(words, date_since, numtweet):
    db = pd.DataFrame(columns=['username', 'description', 'location', 'following',
                               'followers', 'totaltweets', 'retweetcount', 'text', 'hashtags', 'datetime'])
    tweets = tweepy.Cursor(api.search, q=words, lang="en",
                           since=date_since, tweet_mode='extended').items(numtweet)
    list_tweets = [tweet for tweet in tweets]
    i = 1
    for tweet in list_tweets:
        username = tweet.user.screen_name
        description = tweet.user.description
        location = tweet.user.location
        following = tweet.user.friends_count
        followers = tweet.user.followers_count
        totaltweets = tweet.user.statuses_count
        retweetcount = tweet.retweet_count
        hashtags = tweet.entities['hashtags']  
        datetime = tweet.created_at
        try:
            text = tweet.retweeted_status.full_text
        except AttributeError:
            text = tweet.full_text
        hashtext = list()
        for j in range(0, len(hashtags)):
            hashtext.append(hashtags[j]['text'])
        ith_tweet = [username, description, location, following,
                     followers, totaltweets, retweetcount, text, hashtext, datetime]
        db.loc[len(db)] = ith_tweet
        printtweetdata(i, ith_tweet)
        i = i+1
    filename = 'scraped_tweets.csv'
    db.to_csv(filename)
   
if __name__ == '__main__':
    consumer_key = "" 
    consumer_secret = ""
    access_key = ""
    access_secret = ""
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)
    print("Enter Twitter HashTag to search for")
    words = input()
    print("Enter Date since The Tweets are required in yyyy-mm-dd")
    date_since = input()
    numtweet = 1000
    scrape(words, date_since, numtweet)
# Out:
# Enter Twitter HashTag to search for
# #VIX
# Enter Date since The Tweets are required in yyyy-mm-dd
# 2021-09-30
#
# Tweet 1:
# Username:InvariantPersp1
# Description:What are the inviolable constraints on the Global Financial Markets and the Global Economy?
# Location:
# Following Count:5002
# Follower Count:3461
# Total Tweets:44938
# Retweet Count:0
# Tweet Text:#recession ... #StockMarket #Bubble edition
#
# #volatility... awaiting the next #VIX explosion 💥📈 https://t.co/KGtXKk9P1R
# Hashtags Used:['recession', 'StockMarket', 'Bubble', 'volatility', 'VIX']
# datetime:2021-10-02 19:02:04
#
# Tweet 2:
# Username:cyberalgo
# Description:🥇 Research, automation, markets data analysis and price narratives. My views. Wisdom quotes. Profile media (Credit: NASA on the Commons)
# Location:
# Following Count:574
# Follower Count:616
# Total Tweets:79816
# Retweet Count:0
# Tweet Text:#VIX | VIX FUTURES - CBOE FUTURES EXCHANGE | 1170E1
#
# Commitments of Traders (CoT) Legacy Report
# Tuesday, 28 of September of 2021
#
# #CoTReport #COTIndex #CFTC #Futures https://t.co/TUPZyNQTLJ
# Hashtags Used:['VIX', 'CoTReport', 'COTIndex', 'CFTC', 'Futures']
# datetime:2021-10-02 18:53:26
#
# Tweet 3:
# Username:cyberalgo
# Description:🥇 Research, automation, markets data analysis and price narratives. My views. Wisdom quotes. Profile media (Credit: NASA on the Commons)
# Location:
# Following Count:574
# Follower Count:616
# Total Tweets:79816
# Retweet Count:0
# Tweet Text:CoT Index
#
# #VIX | VIX FUTURES - CBOE FUTURES EXCHANGE | 1170E1
#
# Commitments of Traders (CoT) Legacy Report
# Tuesday, 28 of September of 2021
#
# #CoTReport #COTIndex #CFTC #Futures https://t.co/0rPc4d1Esv
# Hashtags Used:['VIX', 'CoTReport', 'COTIndex', 'CFTC', 'Futures']
# datetime:2021-10-02 18:53:13
#
# Tweet 4:
# Username:cyberalgo
# Description:🥇 Research, automation, markets data analysis and price narratives. My views. Wisdom quotes. Profile media (Credit: NASA on the Commons)
# Location:
# Following Count:574
# Follower Count:616
# Total Tweets:79816
# Retweet Count:0
# Tweet Text:Long vs Short
#
# #VIX | VIX FUTURES - CBOE FUTURES EXCHANGE | 1170E1
#
# Commitments of Traders (CoT) Legacy Report
# Tuesday, 28 of September of 2021
#
# #CoTReport #CFTC #Futures https://t.co/Fg4p3cnEB8
# Hashtags Used:['VIX', 'CoTReport', 'CFTC', 'Futures']
# datetime:2021-10-02 18:53:01
#
# Tweet 5:
# Username:TheOmegaOracle
# Description:Especulamos en los mercados organizados y desarrollamos tecnología basada en Inteligencia Artificial. Trading Algorítmico.
# Location:London - Palma de Mallorca
# Following Count:94
# Follower Count:226
# Total Tweets:1511
# Retweet Count:0
# Tweet Text:OTT Weekly Summary $SPX &amp; $COMPQ:
# Important Support Levels!!!
#
# #SP500 (E-MINI C 4,350) ↘️↗️
#
# #Stocks Pullback ↘️↗️
#
# #VIX (21.15) ↘️
#
# Key #SP500
# Above: 4,550
# Below: 4,350/4,300
#
# https://t.co/ViafoZDDwd
#
# #trading #hedgefunds #VisualChart #USA #UE #DAX #markets $Indus #TradeStation https://t.co/qUY3iZEj7a
# Hashtags Used:['SP500', 'Stocks', 'VIX', 'SP500', 'trading', 'hedgefunds', 'VisualChart', 'USA', 'UE', 'DAX', 'markets', 'TradeStation']
# datetime:2021-10-02 18:11:25
#
# Tweet 6:
# Username:Serifashshoppe
# Description:Come and discover our Serious Fashion Shoppe; this is where serious art, passion and fashion take place..! https://t.co/c2KEeHXHdM
# Location:South Florida
# Following Count:2766
# Follower Count:2588
# Total Tweets:56193
# Retweet Count:0
# Tweet Text:Check out NWT VIX BY PAULA HERMANNY FLORENCE KNIT SWIMSUIT ONE-PIECE $242 S SMALL   SFS #VIX https://t.co/bfZTGtOoWf via @eBay
# Hashtags Used:['VIX']
# datetime:2021-10-02 17:47:08
#
# Tweet 7:
# Username:AstroCycle_Net
# Description:
# Location:
# Following Count:0
# Follower Count:4499
# Total Tweets:4386
# Retweet Count:0
# Tweet Text:the #VIX is Bearish to Neutral above 20 but is dropping https://t.co/ypCa1TyeIl
#
# The Put/Calls are Neutral and Highs/Lows are Bearish https://t.co/UMa5s5L3MH
#
# The McClellan's are Bearish but another day up will turn them higher https://t.co/1Aw6aV6PuK
# Hashtags Used:['VIX']
# datetime:2021-10-02 16:21:48
#
# Tweet 8:
# Username:pbmech
# Description:Founder & CEO, @ https://t.co/qqD8VEU8Bl Learn Stock Markets, for the Peace-of-Mind / Buy-&-Forget Investing, in 5 Simple Videos. From an IIT & STANFORD alum.
# Location:Stanford Alum
# Following Count:72
# Follower Count:1688
# Total Tweets:26078
# Retweet Count:0
# Tweet Text:@Trendspider_J It happens only “once in a blue moon” … some people waste money on #VIX options every year … for that once in a decade YUGE Spike … that pays them for the next 10-20 years 😀😀😀 not a ‘routine’ thing to happen often :)
# Hashtags Used:['VIX']
# datetime:2021-10-02 14:07:23
#
# Tweet 9:
# Username:volrock10
# Description:
# Location:
# Following Count:288
# Follower Count:0
# Total Tweets:25
# Retweet Count:29
# Tweet Text:#banknifty view for 1st Oct'21.
#
# The panic might be temporary, we can safely consider this as pull back.
#
# Short Term Trend Reverses Below:- 37,000
#
# Medium Term Trend Changes Below:- 36,500
#
# Long Term Trend Changes Below:- 34,900
#
# #vix #indiavix #trade #nifty #trade #pullback https://t.co/rEgSCMcpIA
# Hashtags Used:['banknifty']
# datetime:2021-10-02 13:00:52
#
# Tweet 10:
# Username:lorinda_connor
# Description:47 year old Mimi, living life one day at a time, have a wonderful man in my life, 3 kids and grandbabies and bonus kids and grandbabies. Love them all!
# Location:
# Following Count:3597
# Follower Count:266
# Total Tweets:8074
# Retweet Count:4
# Tweet Text:Here our take on a classic- fluffy Mexican custard! 🍮
# ✶
# ✶
# ✶
# #madewithEB #onlyfeedmeEB #thEBest #egglandsbest #yolk #custard #sweettreat #desert #yummy #vix #yum #yougetwhatyouputin #bettereggs #Mexican #flan #mexicancustard
# https://t.co/YXRlzL01Eu https://t.co/FaxwWMYgJC
# Hashtags Used:['madewithEB', 'onlyfeedmeEB', 'thEBest', 'egglandsbest', 'yolk']
# datetime:2021-10-02 11:50:18
#
# Tweet 11:
# Username:_RDeveci
# Description:Burada paylaştığım  GRAFİK ve YORUMLAR yalnız beni bağlar ARŞİV AMAÇLIDIR. Kesinlikle YATIRIM TAVSİYESİ DEĞİLDİR.
# Location:Bursa, Türkiye
# Following Count:269
# Follower Count:679
# Total Tweets:3940
# Retweet Count:0
# Tweet Text:Check out my #VIX analysis on @TradingView: https://t.co/vobWqeMCHH
# Hashtags Used:['VIX']
# datetime:2021-10-02 10:47:22
#
# Tweet 12:
# Username:Do_Trading
# Description:Full time adaptative #trading-scalping. Market analysis and unbiased commentary.
# Location:Worldwide
# Following Count:170
# Follower Count:683
# Total Tweets:4479
# Retweet Count:0
# Tweet Text:All this little world would be discreet ...#VIX #SPX #Bond #SPX500 #markets #investment https://t.co/Mq483yZpee
# Hashtags Used:['VIX', 'SPX', 'Bond', 'SPX500', 'markets', 'investment']
# datetime:2021-10-02 08:56:07
#
# Tweet 13:
# Username:msNarsi
# Description:
# Location:Chennai
# Following Count:96
# Follower Count:102
# Total Tweets:2198
# Retweet Count:29
# Tweet Text:#banknifty view for 1st Oct'21.
#
# The panic might be temporary, we can safely consider this as pull back.
#
# Short Term Trend Reverses Below:- 37,000
#
# Medium Term Trend Changes Below:- 36,500
#
# Long Term Trend Changes Below:- 34,900
#
# #vix #indiavix #trade #nifty #trade #pullback https://t.co/rEgSCMcpIA
# Hashtags Used:['banknifty']
# datetime:2021-10-02 07:07:02
#
# Tweet 14:
# Username:buzzsubash
# Description:Data storage architect@HPE.  FnO Trader. Investor.
# Location:Singapore
# Following Count:582
# Follower Count:599
# Total Tweets:47180
# Retweet Count:29
# Tweet Text:#banknifty view for 1st Oct'21.
#
# The panic might be temporary, we can safely consider this as pull back.
#
# Short Term Trend Reverses Below:- 37,000
#
# Medium Term Trend Changes Below:- 36,500
#
# Long Term Trend Changes Below:- 34,900
#
# #vix #indiavix #trade #nifty #trade #pullback https://t.co/rEgSCMcpIA
# Hashtags Used:['banknifty']
# datetime:2021-10-02 06:55:15
#
# Tweet 15:
# Username:buzzsubash
# Description:Data storage architect@HPE.  FnO Trader. Investor.
# Location:Singapore
# Following Count:582
# Follower Count:599
# Total Tweets:47180
# Retweet Count:9
# Tweet Text:#bnf 37284 High Spot cmp 37225
# Baki Monday karenge Upside gap fill
#
# OTM Premiums is High On PE compare to CE
# expect GapUp on monday
#
# #RSPVIEW  #banknifty #VIX https://t.co/pYhjG0c6jD
# Hashtags Used:['bnf']
# datetime:2021-10-02 05:42:32
#
# Tweet 16:
# Username:markones111_
# Description:Stock , penny puncher, silver stacker. ain’t no money made without stacking! silver, pennies are my go to. not financial advice just a dreamer.
# Location:
# Following Count:319
# Follower Count:161
# Total Tweets:4572
# Retweet Count:5
# Tweet Text:US #Markets = Closing Prices: Oct 1
# #DOW 34327.45 +1.43%
# #SPX 4357.09 +1.15%
# #NDX 14791.8 +0.70%
# #VIX 21.23 -1.91
# #DOW +750 = Boomer Bottoms Bouncing with a Buzz
# Anyone feel Silly for Selling out the #ASX on Friday ??
# Hashtags Used:['Markets', 'DOW', 'SPX', 'NDX', 'VIX', 'DOW']
# datetime:2021-10-02 05:39:24
#
# Tweet 17:
# Username:TraderUaau
# Description:
# Location:Brisbane, Queensland
# Following Count:196
# Follower Count:11
# Total Tweets:58
# Retweet Count:5
# Tweet Text:US #Markets = Closing Prices: Oct 1
# #DOW 34327.45 +1.43%
# #SPX 4357.09 +1.15%
# #NDX 14791.8 +0.70%
# #VIX 21.23 -1.91
# #DOW +750 = Boomer Bottoms Bouncing with a Buzz
# Anyone feel Silly for Selling out the #ASX on Friday ??
# Hashtags Used:['Markets', 'DOW', 'SPX', 'NDX', 'VIX', 'DOW']
# datetime:2021-10-02 05:16:52
#
# Tweet 18:
# Username:SaigalSingh
# Description:Guy With Million Dollar Heart , Apathy for the Ones who need Emotional Person Loves to Mingle irrespective of anyone's caste Creed religion & bank balance TRUST
# Location:Durg, India
# Following Count:159
# Follower Count:173
# Total Tweets:44087
# Retweet Count:9
# Tweet Text:#bnf 37284 High Spot cmp 37225
# Baki Monday karenge Upside gap fill
#
# OTM Premiums is High On PE compare to CE
# expect GapUp on monday
#
# #RSPVIEW  #banknifty #VIX https://t.co/pYhjG0c6jD
# Hashtags Used:['bnf']
# datetime:2021-10-02 05:01:14
#
# Tweet 19:
# Username:NCHolt15
# Description:Family, Mates, Ocean, Markets
# Location:
# Following Count:63
# Follower Count:84
# Total Tweets:407
# Retweet Count:0
# Tweet Text:#VIX  doesn't look too fearful to me.
# Pretty sold rejection last night.
# These patterns have been seen before.
# No need to panic yet folks.
# #fear #index #staycalm https://t.co/riOv5EFoZq
# Hashtags Used:['VIX', 'fear', 'index', 'staycalm']
# datetime:2021-10-02 04:24:19
#
# Tweet 20:
# Username:andyfullmetal
# Description:Focusing on Mining, oil, gas and biotech stocks 📈📉📊🗒
#
# Always remember $Gold #Gold is the best insurance against inflation 📍
# Location:Sydney, New South Wales
# Following Count:151
# Follower Count:2220
# Total Tweets:8127
# Retweet Count:5
# Tweet Text:US #Markets = Closing Prices: Oct 1
# #DOW 34327.45 +1.43%
# #SPX 4357.09 +1.15%
# #NDX 14791.8 +0.70%
# #VIX 21.23 -1.91
# #DOW +750 = Boomer Bottoms Bouncing with a Buzz
# Anyone feel Silly for Selling out the #ASX on Friday ??
# Hashtags Used:['Markets', 'DOW', 'SPX', 'NDX', 'VIX', 'DOW']
# datetime:2021-10-02 04:18:00
#
# Tweet 21:
# Username:Eracey3
# Description:
# Location:Perth, Western Australia
# Following Count:37
# Follower Count:91
# Total Tweets:766
# Retweet Count:5
# Tweet Text:US #Markets = Closing Prices: Oct 1
# #DOW 34327.45 +1.43%
# #SPX 4357.09 +1.15%
# #NDX 14791.8 +0.70%
# #VIX 21.23 -1.91
# #DOW +750 = Boomer Bottoms Bouncing with a Buzz
# Anyone feel Silly for Selling out the #ASX on Friday ??
# Hashtags Used:['Markets', 'DOW', 'SPX', 'NDX', 'VIX', 'DOW']
# datetime:2021-10-02 02:58:55
#
# Tweet 22:
# Username:aussieshareguru
# Description:father of 2 kids, full time asx investor now , learning process never ending , realise and learnt only patience is main key for trading. it’s learnt and felt...
# Location:Willetton, Perth (WA)
# Following Count:1291
# Follower Count:701
# Total Tweets:9476
# Retweet Count:5
# Tweet Text:US #Markets = Closing Prices: Oct 1
# #DOW 34327.45 +1.43%
# #SPX 4357.09 +1.15%
# #NDX 14791.8 +0.70%
# #VIX 21.23 -1.91
# #DOW +750 = Boomer Bottoms Bouncing with a Buzz
# Anyone feel Silly for Selling out the #ASX on Friday ??
# Hashtags Used:['Markets', 'DOW', 'SPX', 'NDX', 'VIX', 'DOW']
# datetime:2021-10-02 02:51:35
# Tweet 23:
# Username:Simcoe__
# Description:
# Location:
# Following Count:2068
# Follower Count:92
# Total Tweets:2105
# Retweet Count:3
# Tweet Text:#ReSolveRiffs with Options Ninjas Dr. Benn Eifert and Scott Maidel from QVR Advisors @bennpeifert #options #volatility #VIX #hedging #gamma https://t.co/wY3hzU8DZQ
# Hashtags Used:['ReSolveRiffs', 'options', 'volatility']
# datetime:2021-10-02 02:46:09
#
# Tweet 24:
# Username:gassin123Charts
# Description:Chartist Trader #ASX  : Bottoms = Breakouts = Uptrends = Peaks + Support Zones  ..Hunter
# Location:Sydney, New South Wales
# Following Count:10528
# Follower Count:14803
# Total Tweets:134992
# Retweet Count:5
# Tweet Text:US #Markets = Closing Prices: Oct 1
# #DOW 34327.45 +1.43%
# #SPX 4357.09 +1.15%
# #NDX 14791.8 +0.70%
# #VIX 21.23 -1.91
# #DOW +750 = Boomer Bottoms Bouncing with a Buzz
# Anyone feel Silly for Selling out the #ASX on Friday ??
# Hashtags Used:['Markets', 'DOW', 'SPX', 'NDX', 'VIX', 'DOW', 'ASX']
# datetime:2021-10-02 02:39:44
#
# Tweet 25:
# Username:samstrades
# Description:Full Time Trader/Investor/Data Junkie 🌎 (ES, NQ, SPI)
# Location:
# Following Count:107
# Follower Count:2567
# Total Tweets:50701
# Retweet Count:0
# Tweet Text:The elephant in the room is debt ceiling, expect more downside if the issue isn’t fixed; we will get some serious volatility imo #NASDAQ #ES_F #volatility #vix https://t.co/4qG1gB0aLO
# Hashtags Used:['NASDAQ', 'ES_F', 'volatility', 'vix']
# datetime:2021-10-02 01:59:12
#
# Tweet 26:
# Username:JoseGonzalesc11
# Description:portfolio management specialist/
# joey/joes/
# global market analyst
# Location:sumacab sur, cabanatuan city
# Following Count:2442
# Follower Count:789
# Total Tweets:105669
# Retweet Count:3
# Tweet Text:US Closing Prices:
# #DOW 34327.45 +1.43%
# #SPX 4357.09 +1.15%
# #NDX 14791.8 +0.70%
# #RTY 2241.63 +1.69%
# #VIX 21.23 -1.91
# Hashtags Used:['DOW', 'SPX', 'NDX', 'RTY', 'VIX']
# datetime:2021-10-02 01:29:08
#
# Tweet 27:
# Username:AsteriskZoro
# Description:Stuck in Babel.Modern literature dropout sloppily facing the weight of time
# Location:Milano, Lombardia
# Following Count:953
# Follower Count:65
# Total Tweets:5480
# Retweet Count:2
# Tweet Text:🍹
# Don't forget to join us LIVE on YOUTUBE today at 4 PM EDT!
#
# #ReSolveRiffs with Options Ninjas Dr. Benn Eifert and Scott Maidel from QVR Advisors
#
# Co-hosted by our friend @choffstein!
#
# @bennpeifert #options #volatility #VIX #hedging #gamma
#
# 📌 https://t.co/3SToSuy9oC https://t.co/Qoyk1xahqj
# Hashtags Used:['ReSolveRiffs']
# datetime:2021-10-02 00:22:48
#
# Tweet 28:
# Username:VixPriced
# Description:🤖 Follow me to get hourly VIX price updates
#
# 🚨 Get VIX alerts at https://t.co/9PCa7th9Pi
# Location:
# Following Count:0
# Follower Count:12
# Total Tweets:768
# Retweet Count:0
# Tweet Text:Current  #VIX Price: $21.15 📈
# Hashtags Used:['VIX']
# datetime:2021-10-01 22:01:21
#
# Tweet 29:
# Username:shiftinvesting
# Description:Amateur // Not Investment Advice
# Location:Joplin, MO
# Following Count:184
# Follower Count:5
# Total Tweets:50
# Retweet Count:0
# Tweet Text:Q3 Thread // The equity indices finished the quarter with almost no price increase but lots of volatility along the way. If investors come in selling #volatility soon, we could see prices move back up. #VIX https://t.co/LypDheSm3s
# Hashtags Used:['volatility', 'VIX']
# datetime:2021-10-01 21:30:06
#
# Tweet 30:
# Username:VixPriced
# Description:🤖 Follow me to get hourly VIX price updates
#
# 🚨 Get VIX alerts at https://t.co/9PCa7th9Pi
# Location:
# Following Count:0
# Follower Count:12
# Total Tweets:768
# Retweet Count:0
# Tweet Text:Current  #VIX Price: $21.15 📉
# Hashtags Used:['VIX']
# datetime:2021-10-01 21:01:55
#
# Tweet 31:
# Username:Hiren05409428
# Description:Forex trader | stock trader | Electrical Engineer | Tech guru | Business & Finance
# Location:Rotorua District, New Zealand
# Following Count:280
# Follower Count:18
# Total Tweets:364
# Retweet Count:0
# Tweet Text:#vix taking big support, look at last candle higher high and lower low to confuse traders. Something smells fishy those who understand will short anything #Crypto #stockmarkets #DowJones #ASX200 #gold #silver https://t.co/upJtffbE2a
# Hashtags Used:['vix', 'Crypto', 'stockmarkets', 'DowJones', 'ASX200', 'gold', 'silver']
# datetime:2021-10-01 20:39:40
#
# Tweet 32:
# Username:69NiceBot69
# Description:I retweet almost everything with 69 | managed by @trappermedia | Owned by @DennisS_SH
# Location:
# Following Count:3
# Follower Count:2622
# Total Tweets:1026134
# Retweet Count:1
# Tweet Text:US Closing Prices:
# #DOW 34327.45 +1.43%
# #SPX 4357.09 +1.15%
# #NDX 14791.8 +0.70%
# #RTY 2241.63 +1.69%
# #VIX 21.23 -1.91
# Hashtags Used:['DOW', 'SPX', 'NDX', 'RTY', 'VIX']
# datetime:2021-10-01 20:15:53
#
# Tweet 33:
# Username:Farukb44
# Description:Liberal Party of Canada, +25 years of investment banking experience, Blockchain and Crypto enthusiast, ex Columnist, Photography loving, Sci-Fi, opponent..
# Location:Toronto, Ontario #Earther
# Following Count:3022
# Follower Count:1640
# Total Tweets:43729
# Retweet Count:1
# Tweet Text:US Closing Prices:
# #DOW 34327.45 +1.43%
# #SPX 4357.09 +1.15%
# #NDX 14791.8 +0.70%
# #RTY 2241.63 +1.69%
# #VIX 21.23 -1.91
# Hashtags Used:['DOW', 'SPX', 'NDX', 'RTY', 'VIX']
# datetime:2021-10-01 20:11:34
#
# Tweet 34:
# Username:69NiceBot69
# Description:I retweet almost everything with 69 | managed by @trappermedia | Owned by @DennisS_SH
# Location:
# Following Count:3
# Follower Count:2622
# Total Tweets:1026134
# Retweet Count:3
# Tweet Text:US Closing Prices:
# #DOW 34327.45 +1.43%
# #SPX 4357.09 +1.15%
# #NDX 14791.8 +0.70%
# #RTY 2241.63 +1.69%
# #VIX 21.23 -1.91
# Hashtags Used:['DOW', 'SPX', 'NDX', 'RTY', 'VIX']
# datetime:2021-10-01 20:07:18
#
# Tweet 35:
# Username:trades_social
# Description:Stay on the right side of randomness
# | Futures, ETFs & Cryptos
# | https://t.co/WDsw4KTKcN
# | https://t.co/pZhEUiuYsy
# NOT INVESTMENT ADVICE
# Location:
# Following Count:783
# Follower Count:277
# Total Tweets:2749
# Retweet Count:0
# Tweet Text:Symbol: VXX ⏱️
# Alert: STEAM Summary 📝
# Closing Level: 26.85
# Total Score = -0.88 pts (-0.40R) | Trend Score = -0.88 pts (-0.40R), Exit Score = 0.00 pts (0.00R) #VIX #VXX #vol #ImpliedVol $VIX $VXX #volatility #STEAMguidance #daytrading #trading #scalping https://t.co/ywku3UwJPj
# Hashtags Used:['VIX', 'VXX', 'vol', 'ImpliedVol', 'volatility', 'STEAMguidance', 'daytrading', 'trading', 'scalping']
# datetime:2021-10-01 20:04:24
#
# Tweet 36:
# Username:DrRueckauf
# Description:Digitale Themen - Wirtschaftsnachrichten Wirtschaftspolitik - Umwelt & Naturschutz 🇩🇪🇩🇪🇩🇪🇩🇪
# Location:Deutschland
# Following Count:1955
# Follower Count:3366
# Total Tweets:198890
# Retweet Count:3
# Tweet Text:US Closing Prices:
# #DOW 34327.45 +1.43%
# #SPX 4357.09 +1.15%
# #NDX 14791.8 +0.70%
# #RTY 2241.63 +1.69%
# #VIX 21.23 -1.91
# Hashtags Used:['DOW', 'SPX', 'NDX', 'RTY', 'VIX']
# datetime:2021-10-01 20:03:01
#
# Tweet 37:
# Username:IGSquawk
# Description:From the trading floor - IG dealers share news 24 hours a day. Tweets are not investment advice. Your capital is at risk. 75% of retail CFD accounts lose money.
# Location:Global
# Following Count:671
# Follower Count:57085
# Total Tweets:38836
# Retweet Count:3
# Tweet Text:US Closing Prices:
# #DOW 34327.45 +1.43%
# #SPX 4357.09 +1.15%
# #NDX 14791.8 +0.70%
# #RTY 2241.63 +1.69%
# #VIX 21.23 -1.91
# Hashtags Used:['DOW', 'SPX', 'NDX', 'RTY', 'VIX']
# datetime:2021-10-01 20:01:34
#
# Tweet 38:
# Username:VixPriced
# Description:🤖 Follow me to get hourly VIX price updates
#
# 🚨 Get VIX alerts at https://t.co/9PCa7th9Pi
# Location:
# Following Count:0
# Follower Count:12
# Total Tweets:768
# Retweet Count:0
# Tweet Text:Current  #VIX Price: $21.30 📈
# Hashtags Used:['VIX']
# datetime:2021-10-01 20:01:20
#
# Tweet 39:
# Username:InvestReSolve
# Description:Systematic Global Macro ~ Adaptive Asset Allocation ~ Risk Parity. Robo 2.0. for U.S. Investors. Qualified Persons inquire directly.
# Location:Toronto, Ontario
# Following Count:749
# Follower Count:3560
# Total Tweets:2193
# Retweet Count:3
# Tweet Text:#ReSolveRiffs with Options Ninjas Dr. Benn Eifert and Scott Maidel from QVR Advisors @bennpeifert #options #volatility #VIX #hedging #gamma https://t.co/wY3hzU8DZQ
# Hashtags Used:['ReSolveRiffs', 'options', 'volatility', 'VIX', 'hedging', 'gamma']
# datetime:2021-10-01 20:01:08
#
# Tweet 40:
# Username:GestaltU
# Description:Uncorrelated. Research from ReSolve Asset Management. https://t.co/t0E25eWm1Z. Not investment advice.
# Location:My own head
# Following Count:1948
# Follower Count:8734
# Total Tweets:10966
# Retweet Count:1
# Tweet Text:‼
# We are starting in 15 min!
# Join us live &amp; ask questions!
#
# #ReSolveRiffs with Options Ninjas Dr. Benn Eifert and Scott Maidel from QVR Advisors. Co-hosted by our friend @choffstein.
#
# @bennpeifert #options #volatility #VIX #hedging #gamma
#
# 📌 https://t.co/H5eeI6324A https://t.co/A9RqzzLd84
# Hashtags Used:['ReSolveRiffs']
# datetime:2021-10-01 19:54:35
#
# Tweet 41:
# Username:clkleinmonaco
# Description:Commodity trader/Investor (not advisor). Ags/Energy/Bonds/FX/Indexes https://t.co/D6yf2Sdn2v
# Location:Monaco
# Following Count:296
# Follower Count:2107
# Total Tweets:2658
# Retweet Count:0
# Tweet Text:#VIX told us so 🤷🏻‍♂️ https://t.co/QW4cPRxOuL
# Hashtags Used:['VIX']
# datetime:2021-10-01 19:48:04
#
# Tweet 42:
# Username:InvestReSolve
# Description:Systematic Global Macro ~ Adaptive Asset Allocation ~ Risk Parity. Robo 2.0. for U.S. Investors. Qualified Persons inquire directly.
# Location:Toronto, Ontario
# Following Count:749
# Follower Count:3560
# Total Tweets:2193
# Retweet Count:1
# Tweet Text:‼
# We are starting in 15 min!
# Join us live &amp; ask questions!
#
# #ReSolveRiffs with Options Ninjas Dr. Benn Eifert and Scott Maidel from QVR Advisors. Co-hosted by our friend @choffstein.
#
# @bennpeifert #options #volatility #VIX #hedging #gamma
#
# 📌 https://t.co/H5eeI6324A https://t.co/A9RqzzLd84
# Hashtags Used:['ReSolveRiffs', 'options', 'volatility', 'VIX', 'hedging', 'gamma']
# datetime:2021-10-01 19:45:03
#
# Tweet 43:
# Username:ddubrovskyFX
# Description:Strategist for https://t.co/DGIARLmwsr
# Location:San Francisco, CA
# Following Count:89
# Follower Count:9594
# Total Tweets:4769
# Retweet Count:0
# Tweet Text:The #VIX vol index can be choppy &amp; difficult to interpret sometimes
#
# If I throw a 20-day simple moving average, we can smooth out price action
#
# Over the past month, VIX has been averaging highest closes since April 6th!
#
# Put it another way, we are in an uptrend for volatility https://t.co/JWCT900wKJ
# Hashtags Used:['VIX']
# datetime:2021-10-01 19:30:02
# Tweet 44:
# Username:vixedsignals
# Description:Attempting to read the tea leaves of the volatility complex. Observations and terrible GIFs only. Not advice.
# Location:
# Following Count:39
# Follower Count:50
# Total Tweets:229
# Retweet Count:0
# Tweet Text:Update: VOLs crushed
#
# #vix #vx #vvix #vxx #uvxy #spx https://t.co/NEWMC3XwCr
# Hashtags Used:['vix', 'vx', 'vvix', 'vxx', 'uvxy', 'spx']
# datetime:2021-10-01 19:26:23
#
# Tweet 45:
# Username:UpdatesOil
# Description:A bot tweeting about everything oil and gas related.
# Location:
# Following Count:218
# Follower Count:719
# Total Tweets:102187
# Retweet Count:1
# Tweet Text:#Xiden: "The $4T Is Actually "$0""
#
# Socialist Party: "That's Not Enough"
#
# Checkmate. Make It $400T.
#
# When Math, Science, Economics, Have Literally Been Re-Written By Corrupt Politicians 🦄🚀🚀🚀
#
# #SPX #DJIA #NDX #OOTT #VIX
# Hashtags Used:['Xiden']
# datetime:2021-10-01 19:12:35
#
# Tweet 46:
# Username:PSuiteNetwork
# Description:#WorkingClass | Tweets are not Buy/Sell Advice | Do Your Own Research. Trust No Hedge Fund. Take Profits. Don't Be Greedy.
# Location:NJ NYC Philly AC Central NJ
# Following Count:4368
# Follower Count:1991
# Total Tweets:121635
# Retweet Count:1
# Tweet Text:Current  #VIX Price: $20.86 📉
# Hashtags Used:['VIX']
# datetime:2021-10-01 19:04:14
#
# Tweet 47:
# Username:FUCKALLMMsQ
# Description:🇺🇸 Commodity Trading, Cars, #MAGA 🇺🇸 | Degrees In Both Finance & Economics | Here To Learn & Share Anything Can Happen | Trades Posted Are Not Advice |🖕MMs
# Location:The Moon
# Following Count:331
# Follower Count:829
# Total Tweets:21094
# Retweet Count:1
# Tweet Text:#Xiden: "The $4T Is Actually "$0""
#
# Socialist Party: "That's Not Enough"
#
# Checkmate. Make It $400T.
#
# When Math, Science, Economics, Have Literally Been Re-Written By Corrupt Politicians 🦄🚀🚀🚀
#
# #SPX #DJIA #NDX #OOTT #VIX
# Hashtags Used:['Xiden', 'SPX', 'DJIA', 'NDX', 'OOTT', 'VIX']
# datetime:2021-10-01 19:02:12
#
# Tweet 48:
# Username:VixPriced
# Description:🤖 Follow me to get hourly VIX price updates
#
# 🚨 Get VIX alerts at https://t.co/9PCa7th9Pi
# Location:
# Following Count:0
# Follower Count:12
# Total Tweets:768
# Retweet Count:1
# Tweet Text:Current  #VIX Price: $20.86 📉
# Hashtags Used:['VIX']
# datetime:2021-10-01 19:01:20
#
# Tweet 49:
# Username:Djd551
# Description:Danny, See your future, be your future ... ma, make, make it. *All tweets are for informational purposes only, they do not constitute investment advice.
# Location:Chicago
# Following Count:212
# Follower Count:721
# Total Tweets:1940
# Retweet Count:0
# Tweet Text:$VIX call volume picking up this afternoon. OCT 26 and 37.5 calls most active lines. VIX cash breaking down as the $SPX rallies to the high of the day. VIX futures curve now steeper and roll market out to $1.20 #CBOE #VIX #Volatilty #OptionsTrading  #Futures https://t.co/WnSiJ1gaXE
# Hashtags Used:['CBOE', 'VIX', 'Volatilty', 'OptionsTrading', 'Futures']
# datetime:2021-10-01 18:54:04
#
# Tweet 50:
# Username:Saintsent2
# Description:Crypto degenerate 🤑 IDO flipper 🧧 digital nomad 👨‍💻  and financial freedom advocate 🏄‍♂️
#
# ...to the moon 🚀
# Location:Around the 🌎
# Following Count:3094
# Follower Count:554
# Total Tweets:2935
# Retweet Count:0
# Tweet Text:@rovercrc $GOVI is pretty overlooked right now 🧐
#
# Brother project of $COTI, $GOVI powers https://t.co/gsn0WT0kX0 - volatility trading platform.
#
# This is built around #CVI index = equivalent of #VIX from stocks and it will soon offer some unique features for impermanent loss protection. 🔝 https://t.co/uYXUIFgy9f
# Hashtags Used:['CVI', 'VIX']
# datetime:2021-10-01 18:35:31
#
# Tweet 51:
# Username:charlesdavihat1
# Description:https://t.co/wKVHrQslHF
#
# A.I. / Physics / Fine Art now;
#
# Was a derivatives / finance lawyer;
#
# This one's just better;
#
# Unhinged De Tocqueville of Earth 👽
# Location:New York, NY
# Following Count:3416
# Follower Count:431
# Total Tweets:17569
# Retweet Count:0
# Tweet Text:In good news, the #VIX term structure looks normal, and does not suggest any one-off events:
#
# https://t.co/OjrMl6mfhP
# Hashtags Used:['VIX']
# datetime:2021-10-01 18:34:32
#
# Tweet 52:
# Username:VixPriced
# Description:🤖 Follow me to get hourly VIX price updates
#
# 🚨 Get VIX alerts at https://t.co/9PCa7th9Pi
# Location:
# Following Count:0
# Follower Count:12
# Total Tweets:768
# Retweet Count:0
# Tweet Text:Current  #VIX Price: $21.09 📉
# Hashtags Used:['VIX']
# datetime:2021-10-01 18:01:20
#
# Tweet 53:
# Username:FUCKALLMMsQ
# Description:🇺🇸 Commodity Trading, Cars, #MAGA 🇺🇸 | Degrees In Both Finance & Economics | Here To Learn & Share Anything Can Happen | Trades Posted Are Not Advice |🖕MMs
# Location:The Moon
# Following Count:331
# Follower Count:829
# Total Tweets:21094
# Retweet Count:0
# Tweet Text:They Won't Let It Speak Before Market Closes
#
# @SpeakerPelosi Must Be Holding Calls
#
# #SPX #DJIA #NDX #OOTT #VIX https://t.co/K72HccuMDl
# Hashtags Used:['SPX', 'DJIA', 'NDX', 'OOTT', 'VIX']
# datetime:2021-10-01 18:00:11
#
# Tweet 54:
# Username:Himal_Visharia
# Description:
# Location:
# Following Count:26
# Follower Count:1
# Total Tweets:19
# Retweet Count:29
# Tweet Text:#banknifty view for 1st Oct'21.
#
# The panic might be temporary, we can safely consider this as pull back.
#
# Short Term Trend Reverses Below:- 37,000
#
# Medium Term Trend Changes Below:- 36,500
#
# Long Term Trend Changes Below:- 34,900
#
# #vix #indiavix #trade #nifty #trade #pullback https://t.co/rEgSCMcpIA
# Hashtags Used:['banknifty']
# datetime:2021-10-01 17:55:11
#
# Tweet 55:
# Username:Serifashshoppe
# Description:Come and discover our Serious Fashion Shoppe; this is where serious art, passion and fashion take place..! https://t.co/c2KEeHXHdM
# Location:South Florida
# Following Count:2766
# Follower Count:2588
# Total Tweets:56193
# Retweet Count:0
# Tweet Text:Check out NWT VIX BY PAULA HERMANNY MADISON FLORAL HALTER BIKINI M MEDIUM   SFS #VIX #Bikini https://t.co/XjzAmNQZGZ via @eBay
# Hashtags Used:['VIX', 'Bikini']
# datetime:2021-10-01 17:51:34
#
# Tweet 56:
# Username:potstalking
# Description:#Podcaster for Stalking Pot Stocks, follow me! I’m a strategist for #PotStocks, my post are my opinion, do your own DD before investing
# Location:Los Angeles, CA
# Following Count:190
# Follower Count:327
# Total Tweets:8812
# Retweet Count:0
# Tweet Text:Follow the #VIX
# Hashtags Used:['VIX']
# datetime:2021-10-01 17:26:59
#
# Tweet 57:
# Username:DesoGames
# Description:The Definition of Money: https://t.co/hcJ6fw675b
# The Definitions of Value: https://t.co/Ac9kzrZ1Gv
# Ethereal Value and the Cryptofuture: https://t.co/EFWfG9cHxn
# Location:Netherlands
# Following Count:73
# Follower Count:6089
# Total Tweets:18230
# Retweet Count:1
# Tweet Text:A very VERY good and indepth article that basically shows why i've been pounding the table every time the #VIX dropped to 15-18 to buy long dated VIX calls because *eventually*, it has to go up into a monsterous spike.
#
# https://t.co/FXtSWjg7e5
#
# The warnings are there.... https://t.co/gQI9qEJoBh
# Hashtags Used:['VIX']
# datetime:2021-10-01 17:22:32
#
# Tweet 58:
# Username:VixPriced
# Description:🤖 Follow me to get hourly VIX price updates
#
# 🚨 Get VIX alerts at https://t.co/9PCa7th9Pi
# Location:
# Following Count:0
# Follower Count:12
# Total Tweets:768
# Retweet Count:0
# Tweet Text:Current  #VIX Price: $21.68 📉
# Hashtags Used:['VIX']
# datetime:2021-10-01 17:01:20
#
# Tweet 59:
# Username:Vikash4740
# Description:
# Location:Kolkata, India
# Following Count:76
# Follower Count:42
# Total Tweets:187
# Retweet Count:29
# Tweet Text:#banknifty view for 1st Oct'21.
#
# The panic might be temporary, we can safely consider this as pull back.
#
# Short Term Trend Reverses Below:- 37,000
#
# Medium Term Trend Changes Below:- 36,500
#
# Long Term Trend Changes Below:- 34,900
#
# #vix #indiavix #trade #nifty #trade #pullback https://t.co/rEgSCMcpIA
# Hashtags Used:['banknifty']
# datetime:2021-10-01 16:52:16
#
# Tweet 60:
# Username:nationalistgj06
# Description:
# Location:Vadodara
# Following Count:251
# Follower Count:22
# Total Tweets:1350
# Retweet Count:29
# Tweet Text:#banknifty view for 1st Oct'21.
#
# The panic might be temporary, we can safely consider this as pull back.
#
# Short Term Trend Reverses Below:- 37,000
#
# Medium Term Trend Changes Below:- 36,500
#
# Long Term Trend Changes Below:- 34,900
#
# #vix #indiavix #trade #nifty #trade #pullback https://t.co/rEgSCMcpIA
# Hashtags Used:['banknifty']
# datetime:2021-10-01 16:41:27
#
# Tweet 61:
# Username:Akk11Imr
# Description:
# Location:
# Following Count:48
# Follower Count:3
# Total Tweets:29
# Retweet Count:29
# Tweet Text:#banknifty view for 1st Oct'21.
#
# The panic might be temporary, we can safely consider this as pull back.
#
# Short Term Trend Reverses Below:- 37,000
#
# Medium Term Trend Changes Below:- 36,500
#
# Long Term Trend Changes Below:- 34,900
#
# #vix #indiavix #trade #nifty #trade #pullback https://t.co/rEgSCMcpIA
# Hashtags Used:['banknifty']
# datetime:2021-10-01 16:31:58
#
# Tweet 62:
# Username:red6660d
# Description:‏محلل موجات الليوت ومحلل عملات وسلع ومحلل اسهم
# Location:
# Following Count:103
# Follower Count:10
# Total Tweets:1340
# Retweet Count:0
# Tweet Text:#USA
# #USArmy
#  #الذهب #البترول #النفط #تميم_بن_حمد
# #Europe
# #eurusd  #GBPUSD #usdcad
# #USDJPY #usdcny
# #gold #Oil
# #BTC #BTCUSD
# #FCA #cftc #NFA
#  #iran #ايران
# #usdrub
# #Coffee #CoffeeDay
# #vix #dow30
# #dow
# S&amp;P VIX
# Bey smooll part https://t.co/YeoX5VT0QM
# Hashtags Used:['USA', 'USArmy', 'الذهب', 'البترول', 'النفط', 'تميم_بن_حمد', 'Europe', 'eurusd', 'GBPUSD', 'usdcad', 'USDJPY', 'usdcny', 'gold', 'Oil', 'BTC', 'BTCUSD', 'FCA', 'cftc', 'NFA', 'iran', 'ايران', 'usdrub', 'Coffee', 'CoffeeDay', 'vix', 'dow30', 'dow']
# datetime:2021-10-01 16:06:14
#
# Tweet 63:
# Username:VixPriced
# Description:🤖 Follow me to get hourly VIX price updates
#
# 🚨 Get VIX alerts at https://t.co/9PCa7th9Pi
# Location:
# Following Count:0
# Follower Count:12
# Total Tweets:768
# Retweet Count:0
# Tweet Text:Current  #VIX Price: $21.84 📉
# Hashtags Used:['VIX']
# datetime:2021-10-01 16:01:20
#
# Tweet 64:
# Username:bennpeifert
# Description:☮️ 🚀 Derivatives, volatility and technology. I/we/Gaia. Views my own. Tweets may relate to undisclosed investment holdings. No investment advice. 🚀 ☮️
# Location:San Francisco, CA
# Following Count:1264
# Follower Count:49123
# Total Tweets:29516
# Retweet Count:2
# Tweet Text:🍹
# Don't forget to join us LIVE on YOUTUBE today at 4 PM EDT!
#
# #ReSolveRiffs with Options Ninjas Dr. Benn Eifert and Scott Maidel from QVR Advisors
#
# Co-hosted by our friend @choffstein!
#
# @bennpeifert #options #volatility #VIX #hedging #gamma
#
# 📌 https://t.co/3SToSuy9oC https://t.co/Qoyk1xahqj
# Hashtags Used:['ReSolveRiffs']
# datetime:2021-10-01 15:59:29
#
# Tweet 65:
# Username:buzzsubash
# Description:Data storage architect@HPE.  FnO Trader. Investor.
# Location:Singapore
# Following Count:582
# Follower Count:599
# Total Tweets:47180
# Retweet Count:1
# Tweet Text:# Fear on higher side could reach 25 soon #SPX500 #vix #nifty #banknifty correction next week likely https://t.co/4z457NVwVK
# Hashtags Used:['SPX500', 'vix', 'nifty', 'banknifty']
# datetime:2021-10-01 15:49:20
#
# Tweet 66:
# Username:GallantNicolas1
# Description:Créateur de Momentum https://t.co/yMJle90L6H à @MagazineCapital , newsletter d'#AnalyseTechnique et financière sur la Bourse, les Crypto, l'or... CFTe (IFTA) @Afatenews
# Location:Yvelines, Ile-de-France
# Following Count:53
# Follower Count:1087
# Total Tweets:5230
# Retweet Count:1
# Tweet Text:#VIX looks like it is forming a rounding bottom. Another dangerous pattern. https://t.co/LNoeumdz3b
# Hashtags Used:['VIX']
# datetime:2021-10-01 15:23:41
#
# Tweet 67:
# Username:Hiren05409428
# Description:Forex trader | stock trader | Electrical Engineer | Tech guru | Business & Finance
# Location:Rotorua District, New Zealand
# Following Count:280
# Follower Count:18
# Total Tweets:364
# Retweet Count:1
# Tweet Text:# Fear on higher side could reach 25 soon #SPX500 #vix #nifty #banknifty correction next week likely https://t.co/4z457NVwVK
# Hashtags Used:['SPX500', 'vix', 'nifty', 'banknifty']
# datetime:2021-10-01 15:12:04
#
# Tweet 68:
# Username:DIXIT_4S
# Description:
# Location:
# Following Count:169
# Follower Count:66
# Total Tweets:119
# Retweet Count:29
# Tweet Text:#banknifty view for 1st Oct'21.
#
# The panic might be temporary, we can safely consider this as pull back.
#
# Short Term Trend Reverses Below:- 37,000
#
# Medium Term Trend Changes Below:- 36,500
#
# Long Term Trend Changes Below:- 34,900
#
# #vix #indiavix #trade #nifty #trade #pullback https://t.co/rEgSCMcpIA
# Hashtags Used:['banknifty']
# datetime:2021-10-01 15:10:58
#
# Tweet 69:
# Username:Pappa_Young
# Description:Everything is right, everything is wrong, only perception is correct and the reality. Reality is the truth and the fake truth is the alternate reality
# Location:Borderless
# Following Count:87
# Follower Count:46
# Total Tweets:1748
# Retweet Count:0
# Tweet Text:@ThePivotKing #MFAAANNG
# $MSFT $FB $AAPL $AMZN $AMD $NFLX $NVDA $GOOGL
# $TLSA $QCOM $MU $GS $JPM $PYPL $SPY $QQQ $YM $NQ $ES $YM
# Opppss they figured it out?... hammer the #VIX ? .. lol
# Hashtags Used:['MFAAANNG', 'VIX']
# datetime:2021-10-01 15:03:05
#
# Tweet 70:
# Username:VixPriced
# Description:🤖 Follow me to get hourly VIX price updates
#
# 🚨 Get VIX alerts at https://t.co/9PCa7th9Pi
# Location:
# Following Count:0
# Follower Count:12
# Total Tweets:768
# Retweet Count:0
# Tweet Text:Current  #VIX Price: $22.66 📉
# Hashtags Used:['VIX']
# datetime:2021-10-01 15:01:20
#
# Tweet 71:
# Username:kishan0006
# Description:
# Location:
# Following Count:6
# Follower Count:2
# Total Tweets:6
# Retweet Count:29
# Tweet Text:#banknifty view for 1st Oct'21.
#
# The panic might be temporary, we can safely consider this as pull back.
#
# Short Term Trend Reverses Below:- 37,000
#
# Medium Term Trend Changes Below:- 36,500
#
# Long Term Trend Changes Below:- 34,900
#
# #vix #indiavix #trade #nifty #trade #pullback https://t.co/rEgSCMcpIA
# Hashtags Used:['banknifty']
# datetime:2021-10-01 14:44:22
#
# Tweet 72:
# Username:twittatwott
# Description:Life's a matter of rythm.
# Applied behavioral finance through economic cycles and investor's moods.
# Location:Paris France
# Following Count:204
# Follower Count:1157
# Total Tweets:1129
# Retweet Count:1
# Tweet Text:#VIX looks like it is forming a rounding bottom. Another dangerous pattern. https://t.co/LNoeumdz3b
# Hashtags Used:['VIX']
# datetime:2021-10-01 14:40:26
#
# Tweet 73:
# Username:AstroCycle_Net
# Description:
# Location:
# Following Count:0
# Follower Count:4499
# Total Tweets:4386
# Retweet Count:1
# Tweet Text:The #VIX is Bearish above 20 but below 25 and for a Panic it would break above 25 easily https://t.co/ypCa1TyeIl
#
# The Put/Calls and Highs/Lows are Bearish https://t.co/UMa5s5L3MH
#
# The McClellan's are Bearish and a day or more from oversold https://t.co/1Aw6aV6PuK
# Hashtags Used:['VIX']
# datetime:2021-10-01 14:27:57
#
# Tweet 74:
# Username:se_tradingview
# Description:
# Location:Sverige
# Following Count:0
# Follower Count:618
# Total Tweets:3791
# Retweet Count:0
# Tweet Text:#VIX - VIX 2021-10-01 - TradingView - https://t.co/waD9kQPM2y
# Hashtags Used:['VIX']
# datetime:2021-10-01 14:20:02
#
# Tweet 75:
# Username:vixedsignals
# Description:Attempting to read the tea leaves of the volatility complex. Observations and terrible GIFs only. Not advice.
# Location:
# Following Count:39
# Follower Count:50
# Total Tweets:229
# Retweet Count:0
# Tweet Text:10/1/21 Status: Flashing Yellow
#
# The wide swings in vol futs continue but so far there hasn't been enough fuel to keep these spikes alive. The VVIX divergence noted in the 2nd update yesterday also continues to hold.
#
# Friday crush coming?
#
# #vix #vx #vvix #vxx #uvxy #spx https://t.co/UDSnTmU88b
# Hashtags Used:['vix', 'vx', 'vvix', 'vxx', 'uvxy', 'spx']
# datetime:2021-10-01 14:10:31
#
# Tweet 76:
# Username:rajgubbala
# Description:
# Location:
# Following Count:25
# Follower Count:0
# Total Tweets:8
# Retweet Count:29
# Tweet Text:#banknifty view for 1st Oct'21.
#
# The panic might be temporary, we can safely consider this as pull back.
#
# Short Term Trend Reverses Below:- 37,000
#
# Medium Term Trend Changes Below:- 36,500
#
# Long Term Trend Changes Below:- 34,900
#
# #vix #indiavix #trade #nifty #trade #pullback https://t.co/rEgSCMcpIA
# Hashtags Used:['banknifty']
# datetime:2021-10-01 14:08:15
#
# Tweet 77:
# Username:buzzsubash
# Description:Data storage architect@HPE.  FnO Trader. Investor.
# Location:Singapore
# Following Count:582
# Follower Count:599
# Total Tweets:47180
# Retweet Count:29
# Tweet Text:#banknifty view for 1st Oct'21.
#
# The panic might be temporary, we can safely consider this as pull back.
#
# Short Term Trend Reverses Below:- 37,000
#
# Medium Term Trend Changes Below:- 36,500
#
# Long Term Trend Changes Below:- 34,900
#
# #vix #indiavix #trade #nifty #trade #pullback https://t.co/rEgSCMcpIA
# Hashtags Used:['banknifty']
# datetime:2021-10-01 14:07:36
#
# Tweet 78:
# Username:PSuiteNetwork
# Description:#WorkingClass | Tweets are not Buy/Sell Advice | Do Your Own Research. Trust No Hedge Fund. Take Profits. Don't Be Greedy.
# Location:NJ NYC Philly AC Central NJ
# Following Count:4368
# Follower Count:1991
# Total Tweets:121635
# Retweet Count:1
# Tweet Text:Current  #VIX Price: $22.92 📈
# Hashtags Used:['VIX']
# datetime:2021-10-01 14:01:54
#
# Tweet 79:
# Username:DeepakJ02078163
# Description:
# Location:
# Following Count:197
# Follower Count:31
# Total Tweets:247
# Retweet Count:29
# Tweet Text:#banknifty view for 1st Oct'21.
#
# The panic might be temporary, we can safely consider this as pull back.
#
# Short Term Trend Reverses Below:- 37,000
#
# Medium Term Trend Changes Below:- 36,500
#
# Long Term Trend Changes Below:- 34,900
#
# #vix #indiavix #trade #nifty #trade #pullback https://t.co/rEgSCMcpIA
# Hashtags Used:['banknifty']
# datetime:2021-10-01 14:01:32
#
# Tweet 80:
# Username:InvestReSolve
# Description:Systematic Global Macro ~ Adaptive Asset Allocation ~ Risk Parity. Robo 2.0. for U.S. Investors. Qualified Persons inquire directly.
# Location:Toronto, Ontario
# Following Count:749
# Follower Count:3560
# Total Tweets:2193
# Retweet Count:2
# Tweet Text:🍹
# Don't forget to join us LIVE on YOUTUBE today at 4 PM EDT!
#
# #ReSolveRiffs with Options Ninjas Dr. Benn Eifert and Scott Maidel from QVR Advisors
#
# Co-hosted by our friend @choffstein!
#
# @bennpeifert #options #volatility #VIX #hedging #gamma
#
# 📌 https://t.co/3SToSuy9oC https://t.co/Qoyk1xahqj
# Hashtags Used:['ReSolveRiffs', 'options', 'volatility', 'VIX', 'hedging', 'gamma']
# datetime:2021-10-01 14:01:29
#
# Tweet 81:
# Username:VixPriced
# Description:🤖 Follow me to get hourly VIX price updates
#
# 🚨 Get VIX alerts at https://t.co/9PCa7th9Pi
# Location:
# Following Count:0
# Follower Count:12
# Total Tweets:768
# Retweet Count:1
# Tweet Text:Current  #VIX Price: $22.92 📈
# Hashtags Used:['VIX']
# datetime:2021-10-01 14:01:20
#
# Tweet 82:
# Username:pratiks66430267
# Description:
# Location:Rajkot, India
# Following Count:13
# Follower Count:20
# Total Tweets:33
# Retweet Count:29
# Tweet Text:#banknifty view for 1st Oct'21.
#
# The panic might be temporary, we can safely consider this as pull back.
#
# Short Term Trend Reverses Below:- 37,000
#
# Medium Term Trend Changes Below:- 36,500
#
# Long Term Trend Changes Below:- 34,900
#
# #vix #indiavix #trade #nifty #trade #pullback https://t.co/rEgSCMcpIA
# Hashtags Used:['banknifty']
# datetime:2021-10-01 13:53:45
#
# Tweet 83:
# Username:eyeofdtigeerr
# Description:
# Location:
# Following Count:278
# Follower Count:76
# Total Tweets:7782
# Retweet Count:1
# Tweet Text:If you thought this week was choppy and wild don't expect anything else all of next week given #NFP #friday and ahead of the kick off of the earnings season the following week! No #buybacks for a while!:-) #spx #vix #equities
# Hashtags Used:['NFP', 'friday']
# datetime:2021-10-01 13:51:00
#
# Tweet 84:
# Username:steveswitzerlan
# Description:Professional trader & Investment advisor for a multi family office.
# Location:Geneva Switzerland
# Following Count:27
# Follower Count:4247
# Total Tweets:17667
# Retweet Count:1
# Tweet Text:If you thought this week was choppy and wild don't expect anything else all of next week given #NFP #friday and ahead of the kick off of the earnings season the following week! No #buybacks for a while!:-) #spx #vix #equities
# Hashtags Used:['NFP', 'friday', 'buybacks', 'spx', 'vix', 'equities']
# datetime:2021-10-01 13:44:12
#
# Tweet 85:
# Username:red6660d
# Description:‏محلل موجات الليوت ومحلل عملات وسلع ومحلل اسهم
# Location:
# Following Count:103
# Follower Count:10
# Total Tweets:1340
# Retweet Count:0
# Tweet Text:#USA
# #USArmy
#  #الذهب #البترول #النفط #تميم_بن_حمد
# #Europe
# #eurusd  #GBPUSD #usdcad
# #USDJPY #usdcny
# #gold #Oil
# #BTC #BTCUSD
# #FCA #cftc #NFA
#  #iran #ايران
# #usdrub
# #Coffee #CoffeeDay
# #VIX
# #dow30
# S&amp;p vix
# But support 21.5 https://t.co/YfEPDlsM3n
# Hashtags Used:['USA', 'USArmy', 'الذهب', 'البترول', 'النفط', 'تميم_بن_حمد', 'Europe', 'eurusd', 'GBPUSD', 'usdcad', 'USDJPY', 'usdcny', 'gold', 'Oil', 'BTC', 'BTCUSD', 'FCA', 'cftc', 'NFA', 'iran', 'ايران', 'usdrub', 'Coffee', 'CoffeeDay', 'VIX', 'dow30']
# datetime:2021-10-01 13:35:39
#
# Tweet 86:
# Username:VixPriced
# Description:🤖 Follow me to get hourly VIX price updates
#
# 🚨 Get VIX alerts at https://t.co/9PCa7th9Pi
# Location:
# Following Count:0
# Follower Count:12
# Total Tweets:768
# Retweet Count:0
# Tweet Text:Current  #VIX Price: $22.62 📉
# Hashtags Used:['VIX']
# datetime:2021-10-01 13:01:20
#
# Tweet 87:
# Username:HenryBowels
# Description:-Volatility Derivatives Strategist & Godfather
# Location:
# Following Count:15
# Follower Count:714
# Total Tweets:2226
# Retweet Count:0
# Tweet Text:Volatility - VIX 40+ Tomorrow - #VIX TradingView https://t.co/KqmBCxYATx
# Today, it will be known that Volatility , not the Fed, is The King
# Hashtags Used:['VIX']
# datetime:2021-10-01 12:38:28
#
# Tweet 88:
# Username:PuiFred
# Description:metta, compassion, karmic connections
# Location:
# Following Count:439
# Follower Count:90
# Total Tweets:1068
# Retweet Count:0
# Tweet Text:CAUTION !!! $VIX HIGHER BOTTOMS - #VIX chart on @TradingView https://t.co/p8AbxivcDX
# Hashtags Used:['VIX']
# datetime:2021-10-01 12:11:59
#
# Tweet 89:
# Username:Do_Trading
# Description:Full time adaptative #trading-scalping. Market analysis and unbiased commentary.
# Location:Worldwide
# Following Count:170
# Follower Count:683
# Total Tweets:4479
# Retweet Count:0
# Tweet Text:Drop of market with a no panic VIX. Dangerous silence...#VIX #SPX #SP500 #stocks $SPY #markets #inflation https://t.co/j5TkcoG1Py
# Hashtags Used:['VIX', 'SPX', 'SP500', 'stocks', 'markets', 'inflation']
# datetime:2021-10-01 12:09:00
# Tweet 90:
# Username:Quants_Capital
# Description:Founder Quants Capital | Founder QCAlpha | Option Trader | Hedge Fund Manager | Quant Analyst | Tweets are personal views |
# Location:India
# Following Count:459
# Follower Count:4205
# Total Tweets:1444
# Retweet Count:0
# Tweet Text:@TFallibilist The problem is absence of #VIX Futures once they are available and liquid would love to do only long dated.
# Hashtags Used:['VIX']
# datetime:2021-10-01 12:08:47
#
# Tweet 91:
# Username:VixPriced
# Description:🤖 Follow me to get hourly VIX price updates
#
# 🚨 Get VIX alerts at https://t.co/9PCa7th9Pi
# Location:
# Following Count:0
# Follower Count:12
# Total Tweets:768
# Retweet Count:0
# Tweet Text:Current  #VIX Price: $22.68 📉
# Hashtags Used:['VIX']
# datetime:2021-10-01 12:01:20
#
# Tweet 92:
# Username:PSuiteNetwork
# Description:#WorkingClass | Tweets are not Buy/Sell Advice | Do Your Own Research. Trust No Hedge Fund. Take Profits. Don't Be Greedy.
# Location:NJ NYC Philly AC Central NJ
# Following Count:4368
# Follower Count:1991
# Total Tweets:121635
# Retweet Count:1
# Tweet Text:Current  #VIX Price: $23.84 📉
# Hashtags Used:['VIX']
# datetime:2021-10-01 11:47:18
#
# Tweet 93:
# Username:CozzamaraDaZena
# Description:Views are my own. Tweets intended for information only. Retweets ≠ endorsements. Not investment advice.
# Location:https://discord.gg/A7H3k5Qh
# Following Count:660
# Follower Count:251
# Total Tweets:3744
# Retweet Count:0
# Tweet Text:@NorthmanTrader Lot's of movement for #VIX options with 20 days to expiration on 2021-10-20. This means that the market is positioning in accordance with Yellen warning to Congress to raise debt limit by Oct.18 and avoid economic calamity https://t.co/koTcQcaz3m
# Hashtags Used:['VIX']
# datetime:2021-10-01 11:44:10
#
# Tweet 94:
# Username:VixPriced
# Description:🤖 Follow me to get hourly VIX price updates
#
# 🚨 Get VIX alerts at https://t.co/9PCa7th9Pi
# Location:
# Following Count:0
# Follower Count:12
# Total Tweets:768
# Retweet Count:1
# Tweet Text:Current  #VIX Price: $23.84 📉
# Hashtags Used:['VIX']
# datetime:2021-10-01 11:01:20
#
# Tweet 95:
# Username:CozzamaraDaZena
# Description:Views are my own. Tweets intended for information only. Retweets ≠ endorsements. Not investment advice.
# Location:https://discord.gg/A7H3k5Qh
# Following Count:660
# Follower Count:251
# Total Tweets:3744
# Retweet Count:0
# Tweet Text:#VIX put/call ratio close to the following events:
# 1) Deadline to raise #debtceiling ;
# 2) #FOMC meeting 2-3 November;
# 3) #FOMC meeting 14-15 December;
# 4) #WEF meeting in Davos 17-21 January. https://t.co/bfdcsPNvw6
# Hashtags Used:['VIX', 'debtceiling', 'FOMC', 'FOMC', 'WEF']
# datetime:2021-10-01 10:20:01
#
# Tweet 96:
# Username:HedgeFund
# Description:遊歴算家 投資家 代表取締役社長兼CIO 財団会長 🤖 Deep learning machine
# Location:Tokyo
# Following Count:4201
# Follower Count:2675
# Total Tweets:785
# Retweet Count:0
# Tweet Text:+47% in Sep. Diversify! Volatility is the ONLY buy and hold. Stocks bonds gold and real estate all fell. Vol, skill and short positions are the 3 essential things good investors always have in their portfolios. Go #vix
# Hashtags Used:['vix']
# datetime:2021-10-01 10:19:30
#
# Tweet 97:
# Username:buzzsubash
# Description:Data storage architect@HPE.  FnO Trader. Investor.
# Location:Singapore
# Following Count:582
# Follower Count:599
# Total Tweets:47180
# Retweet Count:9
# Tweet Text:#bnf 37284 High Spot cmp 37225
# Baki Monday karenge Upside gap fill
#
# OTM Premiums is High On PE compare to CE
# expect GapUp on monday
#
# #RSPVIEW  #banknifty #VIX https://t.co/pYhjG0c6jD
# Hashtags Used:['bnf']
# datetime:2021-10-01 10:11:37
#
# Tweet 98:
# Username:GlobalEconomyEN
# Description:Finance, investments, trading.
# The contents you find here are ideas to enable you to make your own decisions, these are not financial advice.
# Location:
# Following Count:106
# Follower Count:286
# Total Tweets:2155
# Retweet Count:0
# Tweet Text:The #VIX is positioned above the attention area https://t.co/jDKSvj0ppY
# Hashtags Used:['VIX']
# datetime:2021-10-01 10:06:29
#
# Tweet 99:
# Username:VixPriced
# Description:🤖 Follow me to get hourly VIX price updates
#
# 🚨 Get VIX alerts at https://t.co/9PCa7th9Pi
# Location:
# Following Count:0
# Follower Count:12
# Total Tweets:768
# Retweet Count:0
# Tweet Text:Current  #VIX Price: $24.07 📉
# Hashtags Used:['VIX']
# datetime:2021-10-01 10:01:21
#
# Tweet 100:
# Username:YMehta_
# Description:Trader, Investor and Student ||
# Telegram: https://t.co/IB9ybE4rMu ||
# YouTube: https://t.co/ECaKWUmxzZ ||
# ...
# datetime:2021-09-30 13:02:36
#
# Tweet 213:
# Username:VixPriced
# Description:🤖 Follow me to get hourly VIX price updates
#
# 🚨 Get VIX alerts at https://t.co/9PCa7th9Pi
# Location:
# Following Count:0
# Follower Count:12
# Total Tweets:768
# Retweet Count:0
# Tweet Text:Current  #VIX Price: $21.70 📉
# Hashtags Used:['VIX']
# datetime:2021-09-30 13:01:21
#
# Tweet 214:
# Username:1cwtBob
# Description:Here for CT. Bought btc December 1, 2017 and I'm still in this biatch https://t.co/GJSjoL7Bc4
# #kaztherealdeal #kazuschrist
# Location:
# Following Count:464
# Follower Count:107
# Total Tweets:656
# Retweet Count:19
# Tweet Text:When have you heard of an entire station dodging a major correction all together before don’t worry I’ll wait 🙂 #VIXANOMICS #VIX https://t.co/6NZl4iZVSh
# Hashtags Used:[]
# datetime:2021-09-30 12:54:03
#
# Tweet 215:
# Username:fleejack
# Description:CEO, Chief Cheerleader & Talent Scout @Race2Diversity
# College Diversity Network https://t.co/tQ1FIUsBNv
# Adjunct Professor @ShawUniversity & @SCSTATE1896
# Location:Cary, NC
# Following Count:2277
# Follower Count:15800
# Total Tweets:246667
# Retweet Count:3
# Tweet Text:Send in the clowns, no gov't shutdown By @KennyPolcari https://t.co/0JEXOx6uwy #Equities #Commodities #VIX #Intermarket #Macroeconomics
# Hashtags Used:['Equities', 'Commodities', 'VIX']
# datetime:2021-09-30 12:26:45
#
# Tweet 216:
# Username:VixPriced
# Description:🤖 Follow me to get hourly VIX price updates
#
# 🚨 Get VIX alerts at https://t.co/9PCa7th9Pi
# Location:
# Following Count:0
# Follower Count:12
# Total Tweets:768
# Retweet Count:0
# Tweet Text:Current  #VIX Price: $21.86 📉
# Hashtags Used:['VIX']
# datetime:2021-09-30 12:01:21
#
# Tweet 217:
# Username:logansilverr
# Description:Currency Analyst for @obrinvesting, Actively trading #forex & #crypto, occasionally dabbling in #stocks.    My tweets are my opinions, not advice
# Location:Tampa, FL
# Following Count:92
# Follower Count:87
# Total Tweets:186
# Retweet Count:0
# Tweet Text:Check out my #VIX analysis on @TradingView:
# An interesting chart to see, the VIX does work with technicals as shown by historical data. I am really interested to see if this continues and if it does we could be in for a ride.
# https://t.co/VHNlPCzcKJ
# Hashtags Used:['VIX']
# datetime:2021-09-30 11:48:59
#
# Tweet 218:
# Username:red6660d
# Description:‏محلل موجات الليوت ومحلل عملات وسلع ومحلل اسهم
# Location:
# Following Count:103
# Follower Count:10
# Total Tweets:1340
# Retweet Count:0
# Tweet Text:#USA
# #USArmy
#  #الذهب #البترول #النفط #تميم_بن_حمد
# #Europe
# #eurusd  #GBPUSD #usdcad
# #USDJPY #usdcny
# #gold #Oil
# #BTC #BTCUSD
# #FCA #cftc #NFA
#  #iran #ايران
# #usdrub
# #SPVIX
# #VIX #DowJones
# But support 21 https://t.co/xJUhjmpgfR
# Hashtags Used:['USA', 'USArmy', 'الذهب', 'البترول', 'النفط', 'تميم_بن_حمد', 'Europe', 'eurusd', 'GBPUSD', 'usdcad', 'USDJPY', 'usdcny', 'gold', 'Oil', 'BTC', 'BTCUSD', 'FCA', 'cftc', 'NFA', 'iran', 'ايران', 'usdrub', 'SPVIX', 'VIX', 'DowJones']
# datetime:2021-09-30 11:36:36
#
# Tweet 219:
# Username:KennyPolcari
# Description:Managing Partner Kace Capital Advisors, Market Analyst Fox Biz, CNN, CNBC Key Note Speaker, @HeadstrongProj. Tweets are my own & not reflective of employer.
# Location:Palm Beach + New York
# Following Count:582
# Follower Count:13902
# Total Tweets:23761
# Retweet Count:3
# Tweet Text:Send in the clowns, no gov't shutdown By @KennyPolcari https://t.co/0JEXOx6uwy #Equities #Commodities #VIX #Intermarket #Macroeconomics
# Hashtags Used:['Equities', 'Commodities', 'VIX']
# datetime:2021-09-30 11:01:37
#
# Tweet 220:
# Username:VixPriced
# Description:🤖 Follow me to get hourly VIX price updates
#
# 🚨 Get VIX alerts at https://t.co/9PCa7th9Pi
# Location:
# Following Count:0
# Follower Count:12
# Total Tweets:768
# Retweet Count:0
# Tweet Text:Current  #VIX Price: $21.94 📈
# Hashtags Used:['VIX']
# datetime:2021-09-30 11:01:20
#
# Tweet 221:
# Username:FXstreetReports
# Description:24/5 real-time forex research
# Location:Barcelona
# Following Count:11
# Follower Count:14082
# Total Tweets:330369
# Retweet Count:3
# Tweet Text:Send in the clowns, no gov't shutdown By @KennyPolcari https://t.co/0JEXOx6uwy #Equities #Commodities #VIX #Intermarket #Macroeconomics
# Hashtags Used:['Equities', 'Commodities', 'VIX', 'Intermarket', 'Macroeconomics']
# datetime:2021-09-30 10:57:56
# Tweet 222:
# Username:cyberalgo
# Description:🥇 Research, automation, markets data analysis and price narratives. My views. Wisdom quotes. Profile media (Credit: NASA on the Commons)
# Location:
# Following Count:574
# Follower Count:616
# Total Tweets:79816
# Retweet Count:0
# Tweet Text:#VIX | VIX FUTURES - CBOE FUTURES EXCHANGE | 1170E1
#
# Commitments of Traders (CoT) Legacy Report
# Tuesday, 21 of September of 2021
#
# #CoTReport #COTIndex #CFTC #Futures https://t.co/L7wEdzQOUo
# Hashtags Used:['VIX', 'CoTReport', 'COTIndex', 'CFTC', 'Futures']
# datetime:2021-09-30 10:29:07
#
# Tweet 223:
# Username:cyberalgo
# Description:🥇 Research, automation, markets data analysis and price narratives. My views. Wisdom quotes. Profile media (Credit: NASA on the Commons)
# Location:
# Following Count:574
# Follower Count:616
# Total Tweets:79816
# Retweet Count:0
# Tweet Text:CoT Index
#
# #VIX | VIX FUTURES - CBOE FUTURES EXCHANGE | 1170E1
#
# Commitments of Traders (CoT) Legacy Report
# Tuesday, 21 of September of 2021
#
# #CoTReport #COTIndex #CFTC #Futures https://t.co/j1L2VJ1tJS
# Hashtags Used:['VIX', 'CoTReport', 'COTIndex', 'CFTC', 'Futures']
# datetime:2021-09-30 10:28:58
#
# Tweet 224:
# Username:cyberalgo
# Description:🥇 Research, automation, markets data analysis and price narratives. My views. Wisdom quotes. Profile media (Credit: NASA on the Commons)
# Location:
# Following Count:574
# Follower Count:616
# Total Tweets:79816
# Retweet Count:0
# Tweet Text:Long vs Short
#
# #VIX | VIX FUTURES - CBOE FUTURES EXCHANGE | 1170E1
#
# Commitments of Traders (CoT) Legacy Report
# Tuesday, 21 of September of 2021
#
# #CoTReport #CFTC #Futures https://t.co/0U8kNPzQx5
# Hashtags Used:['VIX', 'CoTReport', 'CFTC', 'Futures']
# datetime:2021-09-30 10:28:51
#
# Tweet 225:
# Username:Do_Trading
# Description:Full time adaptative #trading-scalping. Market analysis and unbiased commentary.
# Location:Worldwide
# Following Count:170
# Follower Count:683
# Total Tweets:4479
# Retweet Count:1
# Tweet Text:Big moves lower in equity indexes, as SP500, VIX spiking. But there would less panic than to the Evergrande days. Care of VIX reaction. #SP500 #equity #stocks #VIX #Evergrande #Inflation #investment https://t.co/E1869Bmrpp
# Hashtags Used:[]
# datetime:2021-09-30 10:25:29
#
# Tweet 226:
# Username:69NiceBot69
# Description:I retweet almost everything with 69 | managed by @trappermedia | Owned by @DennisS_SH
# Location:
# Following Count:3
# Follower Count:2622
# Total Tweets:1026135
# Retweet Count:1
# Tweet Text:Current  #VIX Price: $21.69 📈
# Hashtags Used:['VIX']
# datetime:2021-09-30 10:06:18
#
# Tweet 227:
# Username:VixPriced
# Description:🤖 Follow me to get hourly VIX price updates
#
# 🚨 Get VIX alerts at https://t.co/9PCa7th9Pi
# Location:
# Following Count:0
# Follower Count:12
# Total Tweets:768
# Retweet Count:1
# Tweet Text:Current  #VIX Price: $21.69 📈
# Hashtags Used:['VIX']
# datetime:2021-09-30 10:01:21
#
# Tweet 228:
# Username:buzzsubash
# Description:Data storage architect@HPE.  FnO Trader. Investor.
# Location:Singapore
# Following Count:582
# Follower Count:599
# Total Tweets:47180
# Retweet Count:1
# Tweet Text:pivot                     17658.17
#  Support               17520.67
#  Support 2 .         17574.18
#  Resistance..        17711.68
#  Resistance 2..... 17795.67...live nifty  levels
#  #vix #Nifty #Banknifty #Markets #OptionsTrading #pcr #INTRADAY #sgxnifty #bearish #bullish https://t.co/dXq2RLbgP5
# Hashtags Used:[]
# datetime:2021-09-30 09:17:48
#
# Tweet 229:
# Username:narulalatesh
# Description:Risk Manager ,Foodie, Coffee Lover. Trades Futures ,Equities ,Commodities and Forex .Founder @EquityDynamo. Views are personal.
# Location:Alwar, India
# Following Count:83
# Follower Count:1189
# Total Tweets:10451
# Retweet Count:0
# Tweet Text:2nd confirmation on it.
# Indicating a short term high has been made on it .
# #indiavix
# #VIX
# #EquityDynamo
# Hashtags Used:['indiavix', 'VIX', 'EquityDynamo']
# datetime:2021-09-30 09:10:16
#
# Tweet 230:
# Username:VixPriced
# Description:🤖 Follow me to get hourly VIX price updates
#
# 🚨 Get VIX alerts at https://t.co/9PCa7th9Pi
# Location:
# Following Count:0
# Follower Count:12
# Total Tweets:768
# Retweet Count:0
# Tweet Text:Current  #VIX Price: $21.12 📈
# Hashtags Used:['VIX']
# datetime:2021-09-30 09:01:21
#
# Tweet 231:
# Username:BankniftyNifty
# Description:Passionate about Stock Markets & Investments.Twitter are commentary only,You must analyze & Trade at your own risk...
# Location:
# Following Count:50
# Follower Count:5046
# Total Tweets:10612
# Retweet Count:1
# Tweet Text:pivot                     17658.17
#  Support               17520.67
#  Support 2 .         17574.18
#  Resistance..        17711.68
#  Resistance 2..... 17795.67...live nifty  levels
#  #vix #Nifty #Banknifty #Markets #OptionsTrading #pcr #INTRADAY #sgxnifty #bearish #bullish https://t.co/dXq2RLbgP5
# Hashtags Used:['vix', 'Nifty', 'Banknifty', 'Markets', 'OptionsTrading', 'pcr', 'INTRADAY', 'sgxnifty', 'bearish', 'bullish']
# datetime:2021-09-30 08:13:45
#
# Tweet 232:
# Username:VixPriced
# Description:🤖 Follow me to get hourly VIX price updates
#
# 🚨 Get VIX alerts at https://t.co/9PCa7th9Pi
# Location:
# Following Count:0
# Follower Count:12
# Total Tweets:768
# Retweet Count:0
# Tweet Text:Current  #VIX Price: $21.05 📉
# Hashtags Used:['VIX']
# datetime:2021-09-30 08:01:20
#
# Tweet 233:
# Username:diamondsforex
# Description:'If you are persistent you will get it. If you are consistent, you will keep it.'  NB:  Neither advice nor a signal service.  RT s are not endorsements.
# Location:UK
# Following Count:3163
# Follower Count:10218
# Total Tweets:97356
# Retweet Count:0
# Tweet Text:#FUTURES - #Cotton top of the leader-board.  #VIX bottom. https://t.co/rQlEg0yS9V
# Hashtags Used:['FUTURES', 'Cotton', 'VIX']
# datetime:2021-09-30 07:00:03
#
# Tweet 234:
# Username:Zeenat_trading
# Description:👉2-3 Daily Profit Signal 🎯
# 👉50-70$ Profit Per Trade💰
# 👉Personalized Assistance👩‍💼
# 👉Proper Risk Management 📈
# 👉Take FREE TRIAL SIGNALS TODAY!🔥💵
# Location:
# Following Count:1707
# Follower Count:226
# Total Tweets:368
# Retweet Count:0
# Tweet Text:US30 SELL  34620
# TP 34590
# TP 34560
# SL 34830
#
# DM ME for right lot size: https://t.co/D1kUob0uc3
#
# #nasdaq #nasdaq100 #nas100 #nas100signals #ustec #nas100usd #us100 #volatility75index #volatility #vix75 #vix #forex #market #forexlifestyle #us30 #uk100 #buy #forexeducator
# Hashtags Used:['nasdaq', 'nasdaq100', 'nas100', 'nas100signals', 'ustec', 'nas100usd', 'us100', 'volatility75index', 'volatility', 'vix75', 'vix', 'forex', 'market', 'forexlifestyle', 'us30', 'uk100', 'buy', 'forexeducator']
# datetime:2021-09-30 06:08:06
#
# Tweet 235:
# Username:thebreakoutblog
# Description:Sharing my trading ideas and happy to connect with fellow traders.
# Just launched recently, feedback is appreciated.
# Location:
# Following Count:0
# Follower Count:11
# Total Tweets:53
# Retweet Count:0
# Tweet Text:RETROSPECTIVE: I captured this move with closed profits that saved me in the recent sell-off. The correction may not be over yet #VIX https://t.co/KtT7y2rTp2 https://t.co/YGkMIS6TSz
# Hashtags Used:['VIX']
# datetime:2021-09-30 05:18:31
#
# Tweet 236:
# Username:volatility911
# Description:At the intersection of global macro, volatility and quantitative.
# Location:
# Following Count:219
# Follower Count:113
# Total Tweets:43
# Retweet Count:8
# Tweet Text:🍹
# Prepare your favorite cocktails and tune in to our VIRTUAL HAPPY HOUR!
#
# #ReSolveRiffs with Options Ninjas Dr. Benn Eifert and Scott Maidel from QVR Advisors
#
# Co-hosted by our friend @choffstein!
#
# @bennpeifert #options #volatility #VIX #hedging #gamma
#
# https://t.co/ej385lJ3sl https://t.co/UWn4KNU3Si
# Hashtags Used:['ReSolveRiffs']
# datetime:2021-09-30 05:11:50
#
# Tweet 237:
# Username:rajkgulati
# Description:Live Long And Prosper 🖖
# Location:Virginia, USA
# Following Count:111
# Follower Count:56
# Total Tweets:637
# Retweet Count:0
# Tweet Text:The macro upheaval: a unique opportunity for microcaps unrelated to current affairs to garnish propelling interest. One example is Alfi Inc $ALF. CEOs should PR all they can NOW, not later when whales return to larger caps. @drpaulpereira #pennysocks #spy #vix #microcap
# Hashtags Used:['pennysocks', 'spy', 'vix', 'microcap']
# datetime:2021-09-30 04:39:37
#
# Tweet 238:
# Username:AlgoQuants
# Description:
# Location:Stockholm, Sweden
# Following Count:0
# Follower Count:40
# Total Tweets:1205
# Retweet Count:0
# Tweet Text:Algo XSTO Fear-Greed Index currently at 17.9. Chg 1D -8.4%. Avg 30D at 15.0 Year high/low 73.1/10.7 #VIX #OMXS30 #AlgoFearGreed #Skräckindex https://t.co/b2TM3JYZdJ
# Hashtags Used:['VIX', 'OMXS30', 'AlgoFearGreed', 'Skräckindex']
# datetime:2021-09-30 04:15:36
#
# Tweet 239:
# Username:BrokeBackRican
# Description:I’m BrokeBackRican.. Welcome to BrokeStreetTrading ✍🏼🔥| TA | Education | Options Trader | Future Seven Figure Trader 📚⚡️ Join up the Discord Free 👇🏼👇🏼
# Location:
# Following Count:104
# Follower Count:1891
# Total Tweets:3695
# Retweet Count:0
# Tweet Text:$VIX
#
# For those curious on if there will be more selloff tomorrow.
#
# Here we have the hourly #VIX index we will see if we breakout the bottom and break under $21 the whole market should push up.
#
# If we breakout to the top and over $25 the market will flush even more. https://t.co/twAJmcxVl7
# Hashtags Used:['VIX']
# datetime:2021-09-30 02:27:06
#
# Tweet 240:
# Username:AstroCycle_Net
# Description:
# Location:
# Following Count:0
# Follower Count:4499
# Total Tweets:4386
# Retweet Count:1
# Tweet Text:The #VIX is Bearish above 20 https://t.co/ypCa1TyeIl
#
# The Put/Calls and Highs/Lows are Neutral https://t.co/UMa5s5L3MH
#
# The McClellan's are turning a bit and Neutral https://t.co/1Aw6aV6PuK
#
# The Up/Down vol. is Bearish but trying to turn https://t.co/Ojb632z36C
# Hashtags Used:['VIX']
# datetime:2021-09-30 01:34:53
#
# Tweet 241:
# Username:JoseGonzalesc11
# Description:portfolio management specialist/
# joey/joes/
# global market analyst
# Location:sumacab sur, cabanatuan city
# Following Count:2442
# Follower Count:789
# Total Tweets:105669
# Retweet Count:3
# Tweet Text:US Closing Prices:
# #DOW 34390.72 +0.26%
# #SPX 4359.46 +0.16%
# #NDX 14752.8 -0.12%
# #RTY 2225.31 -0.20%
# #VIX 22.56 -0.69
# Hashtags Used:['DOW', 'SPX', 'NDX', 'RTY', 'VIX']
# datetime:2021-09-30 00:57:27
#
# Tweet 242:
# Username:Eli23Upaya
# Description:You know something even if you don't know something
# Location:
# Following Count:852
# Follower Count:463
# Total Tweets:2511
# Retweet Count:19
# Tweet Text:When have you heard of an entire station dodging a major correction all together before don’t worry I’ll wait 🙂 #VIXANOMICS #VIX https://t.co/6NZl4iZVSh
# Hashtags Used:[]
# datetime:2021-09-30 00:48:05
# Tweet 243:
# Username:DaveNolesAll85
# Description:Doctorate Physical Therapist, Orthopaedic Clinical Specialist and Fellow of the American Academy of Manual Physical Therapy. Stock Market Enthusiast. AAP Member
# Location:
# Following Count:1046
# Follower Count:131
# Total Tweets:3130
# Retweet Count:8
# Tweet Text:🍹
# Prepare your favorite cocktails and tune in to our VIRTUAL HAPPY HOUR!
#
# #ReSolveRiffs with Options Ninjas Dr. Benn Eifert and Scott Maidel from QVR Advisors
#
# Co-hosted by our friend @choffstein!
#
# @bennpeifert #options #volatility #VIX #hedging #gamma
#
# https://t.co/ej385lJ3sl https://t.co/UWn4KNU3Si
# Hashtags Used:['ReSolveRiffs']
# datetime:2021-09-30 00:34:13
#
# Tweet 244:
# Username:DefinitelyTiki
# Description:Nebula 3 & Disciple of https://t.co/9shorJTwSV & https://t.co/wWPob9ZEz0
# Location:
# Following Count:794
# Follower Count:2466
# Total Tweets:1147
# Retweet Count:19
# Tweet Text:When have you heard of an entire station dodging a major correction all together before don’t worry I’ll wait 🙂 #VIXANOMICS #VIX https://t.co/6NZl4iZVSh
# Hashtags Used:[]
# datetime:2021-09-30 00:26:56
#
# Tweet 245:
# Username:InvariantPersp1
# Description:What are the inviolable constraints on the Global Financial Markets and the Global Economy?
# Location:
# Following Count:5002
# Follower Count:3461
# Total Tweets:44938
# Retweet Count:0
# Tweet Text:#recession ... #StockMarket #Bubble edition
#
# Teeing up the next sudden deleveraging cycle... #Volatility #VIX 📈 https://t.co/pyF9zlHC6Y
# Hashtags Used:['recession', 'StockMarket', 'Bubble', 'Volatility', 'VIX']
# datetime:2021-09-30 00:16:08
